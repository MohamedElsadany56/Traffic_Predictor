# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd

file_path = "/content/drive/MyDrive/Machine Project/Motor_Vehicle_Collisions_22-25 .csv"
df = pd.read_csv(file_path)
df
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#        CRASH DATE CRASH TIME BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0      01/01/2022      13:07  QUEENS   11373.0  40.742737 -73.876430
# 1      01/01/2022       2:09  QUEENS   11435.0  40.714996 -73.810220
# 2      01/01/2022       5:55  QUEENS   11435.0  40.693344 -73.802280
# 3      01/01/2022       8:00  QUEENS   11372.0  40.750810 -73.893980
# 4      01/01/2022      18:25  QUEENS   11428.0  40.718513 -73.756386
# ...           ...        ...     ...       ...        ...        ...
# 60279  05/17/2025      22:20  QUEENS   11426.0  40.726788 -73.716310
# 60280  05/17/2025       3:25  QUEENS   11354.0        NaN        NaN
# 60281  05/17/2025      20:30  QUEENS   11369.0  40.764404 -73.869970
# 60282  05/17/2025       0:01  QUEENS   11430.0  40.666620 -73.810460
# 60283  05/17/2025      21:11  QUEENS   11372.0  40.747440 -73.884690
#
#                       LOCATION  ON STREET NAME CROSS STREET NAME  \
# 0       (40.742737, -73.87643)             NaN               NaN
# 1       (40.714996, -73.81022)      150 STREET   COOLIDGE AVENUE
# 2       (40.693344, -73.80228)  WALTHAM STREET        107 AVENUE
# 3        (40.75081, -73.89398)       72 STREET         35 AVENUE
# 4      (40.718513, -73.756386)       90 AVENUE        207 STREET
# ...                        ...             ...               ...
# 60279   (40.726788, -73.71631)             NaN               NaN
# 60280                      NaN          150 ST         28 avenue
# 60281   (40.764404, -73.86997)             NaN               NaN
# 60282    (40.66662, -73.81046)       BELT PKWY            130 ST
# 60283    (40.74744, -73.88469)             NaN               NaN
#
#                OFF STREET NAME  ...   CONTRIBUTING FACTOR VEHICLE 2  \
# 0          89-22     43 AVENUE  ...                     Unspecified
# 1                          NaN  ...                     Unspecified
# 2                          NaN  ...  Driver Inattention/Distraction
# 3                          NaN  ...                     Unspecified
# 4                          NaN  ...                     Unspecified
# ...                        ...  ...                             ...
# 60279   248-55    JERICHO TPKE  ...                     Unspecified
# 60280                      NaN  ...                     Unspecified
# 60281         25-12     100 ST  ...                     Unspecified
# 60282                      NaN  ...                     Unspecified
# 60283  81-02     ROOSEVELT AVE  ...                     Unspecified
#
#        CONTRIBUTING FACTOR VEHICLE 3  CONTRIBUTING FACTOR VEHICLE 4  \
# 0                        Unspecified                            NaN
# 1                                NaN                            NaN
# 2                        Unspecified                    Unspecified
# 3                                NaN                            NaN
# 4                        Unspecified                            NaN
# ...                              ...                            ...
# 60279                            NaN                            NaN
# 60280                            NaN                            NaN
# 60281                            NaN                            NaN
# 60282                            NaN                            NaN
# 60283                            NaN                            NaN
#
#        CONTRIBUTING FACTOR VEHICLE 5  COLLISION_ID  \
# 0                                NaN       4491843
# 1                                NaN       4491064
# 2                        Unspecified       4491624
# 3                                NaN       4491163
# 4                                NaN       4491415
# ...                              ...           ...
# 60279                            NaN       4813994
# 60280                            NaN       4813698
# 60281                            NaN       4813963
# 60282                            NaN       4813728
# 60283                            NaN       4813784
#
#                        VEHICLE TYPE CODE 1  \
# 0                                    Sedan
# 1                                    Sedan
# 2      Station Wagon/Sport Utility Vehicle
# 3                                     Taxi
# 4                                    Sedan
# ...                                    ...
# 60279  Station Wagon/Sport Utility Vehicle
# 60280                                Sedan
# 60281  Station Wagon/Sport Utility Vehicle
# 60282                                Sedan
# 60283                                Sedan
#
#                        VEHICLE TYPE CODE 2  \
# 0                                    Sedan
# 1                                    Sedan
# 2      Station Wagon/Sport Utility Vehicle
# 3                                    Sedan
# 4                                    Sedan
# ...                                    ...
# 60279                                Sedan
# 60280  Station Wagon/Sport Utility Vehicle
# 60281                                Sedan
# 60282                                Sedan
# 60283                                moped
#
#                        VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4  \
# 0      Station Wagon/Sport Utility Vehicle                 NaN
# 1                                      NaN                 NaN
# 2      Station Wagon/Sport Utility Vehicle               Sedan
# 3                                      NaN                 NaN
# 4                                    Sedan                 NaN
# ...                                    ...                 ...
# 60279                                  NaN                 NaN
# 60280                                  NaN                 NaN
# 60281                                  NaN                 NaN
# 60282                                  NaN                 NaN
# 60283                                  NaN                 NaN
#
#       VEHICLE TYPE CODE 5
# 0                     NaN
# 1                     NaN
# 2           Pick-up Truck
# 3                     NaN
# 4                     NaN
# ...                   ...
# 60279                 NaN
# 60280                 NaN
# 60281                 NaN
# 60282                 NaN
# 60283                 NaN
#
# [60284 rows x 29 columns]

# %% [markdown]
# # Data Cleaning

# %%
df.columns
# Out:
# Index(['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE',
#        'LONGITUDE', 'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME',
#        'OFF STREET NAME', 'NUMBER OF PERSONS INJURED',
#        'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED',
#        'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED',
#        'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED',
#        'NUMBER OF MOTORIST KILLED', 'CONTRIBUTING FACTOR VEHICLE 1',
#        'CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3',
#        'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5',
#        'COLLISION_ID', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
#        'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# CRASH DATE                           0
# CRASH TIME                           0
# BOROUGH                              0
# ZIP CODE                            34
# LATITUDE                          1054
# LONGITUDE                         1054
# LOCATION                          1054
# ON STREET NAME                   21321
# CROSS STREET NAME                21372
# OFF STREET NAME                  38963
# NUMBER OF PERSONS INJURED            0
# NUMBER OF PERSONS KILLED             0
# NUMBER OF PEDESTRIANS INJURED        0
# NUMBER OF PEDESTRIANS KILLED         0
# NUMBER OF CYCLIST INJURED            0
# NUMBER OF CYCLIST KILLED             0
# NUMBER OF MOTORIST INJURED           0
# NUMBER OF MOTORIST KILLED            0
# CONTRIBUTING FACTOR VEHICLE 1      363
# CONTRIBUTING FACTOR VEHICLE 2    14424
# CONTRIBUTING FACTOR VEHICLE 3    54370
# CONTRIBUTING FACTOR VEHICLE 4    58693
# CONTRIBUTING FACTOR VEHICLE 5    59801
# COLLISION_ID                         0
# VEHICLE TYPE CODE 1                984
# VEHICLE TYPE CODE 2              21616
# VEHICLE TYPE CODE 3              54868
# VEHICLE TYPE CODE 4              58775
# VEHICLE TYPE CODE 5              59819
# dtype: int64

# %% [markdown]
# Dropping unnecessary columns

# %%
df.drop(columns=['NUMBER OF PEDESTRIANS INJURED',
       'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED',
       'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED','NUMBER OF PERSONS INJURED','NUMBER OF PERSONS KILLED',
       'NUMBER OF MOTORIST KILLED','CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3',
       'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5','VEHICLE TYPE CODE 2',
       'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5','OFF STREET NAME','CROSS STREET NAME','ON STREET NAME'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60284 entries, 0 to 60283
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   CRASH DATE                     60284 non-null  object
#  1   CRASH TIME                     60284 non-null  object
#  2   BOROUGH                        60284 non-null  object
#  3   ZIP CODE                       60250 non-null  float64
#  4   LATITUDE                       59230 non-null  float64
#  5   LONGITUDE                      59230 non-null  float64
#  6   LOCATION                       59230 non-null  object
#  7   CONTRIBUTING FACTOR VEHICLE 1  59921 non-null  object
#  8   COLLISION_ID                   60284 non-null  int64
#  9   VEHICLE TYPE CODE 1            59300 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 4.6+ MB

# %%
df.isnull().sum()
# Out:
# CRASH DATE                          0
# CRASH TIME                          0
# BOROUGH                             0
# ZIP CODE                           34
# LATITUDE                         1054
# LONGITUDE                        1054
# LOCATION                         1054
# CONTRIBUTING FACTOR VEHICLE 1     363
# COLLISION_ID                        0
# VEHICLE TYPE CODE 1               984
# dtype: int64

# %% [markdown]
# Handling Missing Value

# %%
#drop missing values from zip code
df.dropna(subset=['ZIP CODE','LATITUDE', 'LONGITUDE', 'LOCATION'], inplace=True)

# %%
df['CONTRIBUTING FACTOR VEHICLE 1'].fillna('Unspecified', inplace=True)

# %%
most_common_vehicle = df['VEHICLE TYPE CODE 1'].mode()[0]

df['VEHICLE TYPE CODE 1'].fillna(most_common_vehicle, inplace=True)

print(f"Missing 'VEHICLE TYPE CODE 1' filled with: {most_common_vehicle}")

# %%
df.isnull().sum()
# Out:
# CRASH DATE                       0
# CRASH TIME                       0
# BOROUGH                          0
# ZIP CODE                         0
# LATITUDE                         0
# LONGITUDE                        0
# LOCATION                         0
# CONTRIBUTING FACTOR VEHICLE 1    0
# COLLISION_ID                     0
# VEHICLE TYPE CODE 1              0
# dtype: int64

# %% [markdown]
# adding h/d/m to df

# %%
#one date time
df['CRASH_DATETIME'] = pd.to_datetime(df['CRASH DATE'] + ' ' + df['CRASH TIME'],
                                      format='%m/%d/%Y %H:%M', errors='coerce')

df['hour'] = df['CRASH_DATETIME'].dt.hour
df['day'] = df['CRASH_DATETIME'].dt.dayofweek # 0 = Monday, 6 = Sunday
df['month'] = df['CRASH_DATETIME'].dt.month
#drop originaaall
df.drop(columns=['CRASH DATE', 'CRASH TIME'], inplace=True)

df
# Out:
#       BOROUGH  ZIP CODE   LATITUDE  LONGITUDE                 LOCATION  \
# 0      QUEENS   11373.0  40.742737 -73.876430   (40.742737, -73.87643)
# 1      QUEENS   11435.0  40.714996 -73.810220   (40.714996, -73.81022)
# 2      QUEENS   11435.0  40.693344 -73.802280   (40.693344, -73.80228)
# 3      QUEENS   11372.0  40.750810 -73.893980    (40.75081, -73.89398)
# 4      QUEENS   11428.0  40.718513 -73.756386  (40.718513, -73.756386)
# ...       ...       ...        ...        ...                      ...
# 60278  QUEENS   11419.0  40.690030 -73.812830    (40.69003, -73.81283)
# 60279  QUEENS   11426.0  40.726788 -73.716310   (40.726788, -73.71631)
# 60281  QUEENS   11369.0  40.764404 -73.869970   (40.764404, -73.86997)
# 60282  QUEENS   11430.0  40.666620 -73.810460    (40.66662, -73.81046)
# 60283  QUEENS   11372.0  40.747440 -73.884690    (40.74744, -73.88469)
#
#         CONTRIBUTING FACTOR VEHICLE 1  COLLISION_ID  \
# 0      Driver Inattention/Distraction       4491843
# 1               Following Too Closely       4491064
# 2      Driver Inattention/Distraction       4491624
# 3                 Driver Inexperience       4491163
# 4                 Alcohol Involvement       4491415
# ...                               ...           ...
# 60278  Passing or Lane Usage Improper       4813742
# 60279                Backing Unsafely       4813994
# 60281  Driver Inattention/Distraction       4813963
# 60282                    Unsafe Speed       4813728
# 60283  Driver Inattention/Distraction       4813784
#
#                        VEHICLE TYPE CODE 1      CRASH_DATETIME  hour  day  \
# 0                                    Sedan 2022-01-01 13:07:00    13    5
# 1                                    Sedan 2022-01-01 02:09:00     2    5
# 2      Station Wagon/Sport Utility Vehicle 2022-01-01 05:55:00     5    5
# 3                                     Taxi 2022-01-01 08:00:00     8    5
# 4                                    Sedan 2022-01-01 18:25:00    18    5
# ...                                    ...                 ...   ...  ...
# 60278  Station Wagon/Sport Utility Vehicle 2025-05-17 01:30:00     1    5
# 60279  Station Wagon/Sport Utility Vehicle 2025-05-17 22:20:00    22    5
# 60281  Station Wagon/Sport Utility Vehicle 2025-05-17 20:30:00    20    5
# 60282                                Sedan 2025-05-17 00:01:00     0    5
# 60283                                Sedan 2025-05-17 21:11:00    21    5
#
#        month
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 60278      5
# 60279      5
# 60281      5
# 60282      5
# 60283      5
#
# [59198 rows x 12 columns]

# %%
cleaned_path = "/content/drive/MyDrive/Machine Project/nyc_queens_collisions_cleaned.csv"
df.to_csv(cleaned_path, index=False)
print("Cleeaned")
# Out:
# Cleeaned

# %% [markdown]
# # Visualizations

# %% [markdown]
# Hourly collisions

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
sns.countplot(data=df, x='hour', palette='coolwarm')
plt.title('Collisions by Hour of Day')
plt.xlabel('Hour (24h)')
plt.ylabel('Number of Collisions')
plt.grid(True)
plt.show()

# %% [markdown]
# weekly collisions

# %%
days = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
plt.figure(figsize=(10,5))
sns.countplot(data=df, x='day', order=range(7), palette='viridis')
plt.title('Collisions by Day of the Week')
plt.xlabel('Day')
plt.ylabel('Number of Collisions')
plt.xticks(ticks=range(7), labels=days)
plt.grid(True)
plt.show()
#nearly the same rate of weekly collisions
